# %% [markdown]
# ### Linear regression
# a statistical model used to predict the relationship between a dependent variable (y) and one or more independent variables (x).
#
# Mathematically: y = m*x +c
#
# we will use *scikit-learn* library to perform linear regression.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
